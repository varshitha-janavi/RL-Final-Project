# %%
import gymnasium
print(gymnasium.__version__)
# Out:
# 1.0.0

# %%
from stable_baselines3 import PPO
from sb3_contrib import TRPO
from stable_baselines3.common.callbacks import BaseCallback
from stable_baselines3.common.monitor import Monitor
from stable_baselines3.common.vec_env import DummyVecEnv
import gymnasium as gym
import numpy as np
import random
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
# from gym.wrappers import TimeLimit
# from gymnasium.wrappers import TimeLimit
# from stable_baselines3.common.vec_env import SubprocVecEnv  # Import SubprocVecEnv
# Out:
# 2024-11-27 17:49:19.365906: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2024-11-27 17:49:19.374442: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1732754959.383910   17846 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1732754959.386709   17846 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-11-27 17:49:19.397891: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI AVX512_BF16 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
# Custom callback for tracking rewards
class RewardTrackingCallback(BaseCallback):
    def __init__(self, moving_avg_window=100, verbose=0):
        super(RewardTrackingCallback, self).__init__(verbose)
        self.episode_rewards = []
        self.moving_avg_rewards = []
        self.moving_avg_window = moving_avg_window
        self.current_rewards = 0

    def _on_step(self) -> bool:
        self.current_rewards += self.locals["rewards"][-1]
        if self.locals["dones"][-1]:
            self.episode_rewards.append(self.current_rewards)
            moving_avg = (
                np.mean(self.episode_rewards[-self.moving_avg_window:])
                if len(self.episode_rewards) > self.moving_avg_window
                else np.mean(self.episode_rewards)
            )
            self.moving_avg_rewards.append(moving_avg)
            self.current_rewards = 0
        return True

# %%
# Plot function using seaborn
def plot_rewards_across_seeds(data, title):
    sns.set(style="whitegrid")
    plt.figure(figsize=(14, 8))
    sns.lineplot(data=data, x="Episode", y="Reward", hue="Algorithm", style="Seed")
    plt.title(title)
    plt.xlabel("Episodes")
    plt.ylabel("Reward")
    plt.legend(title="Algorithm and Seed")
    plt.show()

# %%
# Function to train models and log results
def train_and_log(env_name, seeds, total_timesteps):
    results = []
    for seed in seeds:
        random.seed(seed)
        np.random.seed(seed)

        vec_env = DummyVecEnv([lambda: Monitor(gym.make(env_name))])

        # PPO Training
        # ppo_model = PPO("MlpPolicy", vec_env, verbose=0, seed=seed, device="cpu")
        # Train PPO
        ppo_model = PPO(
            "MlpPolicy",
            vec_env,
            verbose=2,  # Increase verbosity
            seed=seed,
            device="cpu",
            learning_rate=3e-4,
            n_steps=2048,
            batch_size=64,
            gamma=0.99,
            clip_range=0.2,
            ent_coef=0.01,
            gae_lambda=0.95,
        )
        ppo_callback = RewardTrackingCallback(verbose=0)
        ppo_model.learn(total_timesteps=total_timesteps, callback=ppo_callback)

        for i, reward in enumerate(ppo_callback.episode_rewards):
            results.append({"Episode": i + 1, "Reward": reward, "Algorithm": "PPO", "Seed": f"Seed {seed}"})

        # TRPO Training
        # trpo_model = TRPO("MlpPolicy", vec_env, verbose=0, seed=seed, device="cpu")
        trpo_model = TRPO(
            "MlpPolicy",
            vec_env,
            verbose=1,  # Increase verbosity for debugging
            seed=seed,
            device="cpu",
            gamma=0.99,
            gae_lambda=0.95,
        )
        trpo_callback = RewardTrackingCallback(verbose=0)
        trpo_model.learn(total_timesteps=total_timesteps, callback=trpo_callback)

        for i, reward in enumerate(trpo_callback.episode_rewards):
            results.append({"Episode": i + 1, "Reward": reward, "Algorithm": "TRPO", "Seed": f"Seed {seed}"})

        vec_env.close()
        # ppoName = "ppo_seed:" 
        # ppoName = ppoName + str(seed)
        # ppo_model.save(ppoName)

        # trpoName = "trpo_seed:" 
        # trpoName = trpoName + str(seed)
        # trpo_model.save(trpoName)

          # Save models
        ppo_model.save(f"ppo_seed_long_hyper_{seed}")
        trpo_model.save(f"trpo_seed_long_hyper_{seed}")

    
    return pd.DataFrame(results), ppo_model , trpo_model

# %%
# Configuration
env_name = "LunarLander-v3"
seeds = [42, 100, 123, 2024, 999]
# seeds = [42]
# total_timesteps = 2500000  # 2.5 Millon
total_timesteps = 2500

# %%
# Train models and collect results
print("Training models on different seeds...")
results_df, ppo_model, trpo_model = train_and_log(env_name, seeds, total_timesteps)
# Out:
# Training models on different seeds...
# Using cpu device
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 94.8     |
# |    ep_rew_mean     | -190     |
# | time/              |          |
# |    fps             | 3840     |
# |    iterations      | 1        |
# |    time_elapsed    | 0        |
# |    total_timesteps | 2048     |
# ---------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 94.1         |
# |    ep_rew_mean          | -179         |
# | time/                   |              |
# |    fps                  | 2681         |
# |    iterations           | 2            |
# |    time_elapsed         | 1            |
# |    total_timesteps      | 4096         |
# | train/                  |              |
# |    approx_kl            | 0.0041115778 |
# |    clip_fraction        | 0.00718      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.38        |
# |    explained_variance   | 0.000313     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 561          |
# |    n_updates            | 10           |
# |    policy_gradient_loss | -0.00464     |
# |    value_loss           | 1.66e+03     |
# ------------------------------------------
# Using cpu device
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 94.8     |
# |    ep_rew_mean     | -190     |
# | time/              |          |
# |    fps             | 3929     |
# |    iterations      | 1        |
# |    time_elapsed    | 0        |
# |    total_timesteps | 2048     |
# ---------------------------------
# ----------------------------------------
# | rollout/                  |          |
# |    ep_len_mean            | 97       |
# |    ep_rew_mean            | -192     |
# | time/                     |          |
# |    fps                    | 3569     |
# |    iterations             | 2        |
# |    time_elapsed           | 1        |
# |    total_timesteps        | 4096     |
# | train/                    |          |
# |    explained_variance     | 0.000313 |
# |    is_line_search_success | 1        |
# |    kl_divergence_loss     | 0.00494  |
# |    learning_rate          | 0.001    |
# |    n_updates              | 1        |
# |    policy_objective       | 0.0159   |
# |    value_loss             | 1.51e+03 |
# ----------------------------------------
# Using cpu device
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 95.2     |
# |    ep_rew_mean     | -163     |
# | time/              |          |
# |    fps             | 3896     |
# |    iterations      | 1        |
# |    time_elapsed    | 0        |
# |    total_timesteps | 2048     |
# ---------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 93.7         |
# |    ep_rew_mean          | -178         |
# | time/                   |              |
# |    fps                  | 2942         |
# |    iterations           | 2            |
# |    time_elapsed         | 1            |
# |    total_timesteps      | 4096         |
# | train/                  |              |
# |    approx_kl            | 0.0048957802 |
# |    clip_fraction        | 0.0102       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.38        |
# |    explained_variance   | 0.00209      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 456          |
# |    n_updates            | 10           |
# |    policy_gradient_loss | -0.00574     |
# |    value_loss           | 1.41e+03     |
# ------------------------------------------
# Using cpu device
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 95.2     |
# |    ep_rew_mean     | -163     |
# | time/              |          |
# |    fps             | 3940     |
# |    iterations      | 1        |
# |    time_elapsed    | 0        |
# |    total_timesteps | 2048     |
# ---------------------------------
# ----------------------------------------
# | rollout/                  |          |
# |    ep_len_mean            | 93.5     |
# |    ep_rew_mean            | -190     |
# | time/                     |          |
# |    fps                    | 3609     |
# |    iterations             | 2        |
# |    time_elapsed           | 1        |
# |    total_timesteps        | 4096     |
# | train/                    |          |
# |    explained_variance     | 0.00209  |
# |    is_line_search_success | 1        |
# |    kl_divergence_loss     | 0.00411  |
# |    learning_rate          | 0.001    |
# |    n_updates              | 1        |
# |    policy_objective       | 0.0182   |
# |    value_loss             | 1.29e+03 |
# ----------------------------------------
# Using cpu device
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 88.5     |
# |    ep_rew_mean     | -218     |
# | time/              |          |
# |    fps             | 3930     |
# |    iterations      | 1        |
# |    time_elapsed    | 0        |
# |    total_timesteps | 2048     |
# ---------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 90           |
# |    ep_rew_mean          | -189         |
# | time/                   |              |
# |    fps                  | 2950         |
# |    iterations           | 2            |
# |    time_elapsed         | 1            |
# |    total_timesteps      | 4096         |
# | train/                  |              |
# |    approx_kl            | 0.0060140323 |
# |    clip_fraction        | 0.0314       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.38        |
# |    explained_variance   | 0.000325     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 944          |
# |    n_updates            | 10           |
# |    policy_gradient_loss | -0.00833     |
# |    value_loss           | 1.97e+03     |
# ------------------------------------------
# Using cpu device
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 88.5     |
# |    ep_rew_mean     | -218     |
# | time/              |          |
# |    fps             | 3715     |
# |    iterations      | 1        |
# |    time_elapsed    | 0        |
# |    total_timesteps | 2048     |
# ---------------------------------
# ----------------------------------------
# | rollout/                  |          |
# |    ep_len_mean            | 89.8     |
# |    ep_rew_mean            | -182     |
# | time/                     |          |
# |    fps                    | 3489     |
# |    iterations             | 2        |
# |    time_elapsed           | 1        |
# |    total_timesteps        | 4096     |
# | train/                    |          |
# |    explained_variance     | 0.000325 |
# |    is_line_search_success | 1        |
# |    kl_divergence_loss     | 0.00747  |
# |    learning_rate          | 0.001    |
# |    n_updates              | 1        |
# |    policy_objective       | 0.0164   |
# |    value_loss             | 1.76e+03 |
# ----------------------------------------
# Using cpu device
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 89.7     |
# |    ep_rew_mean     | -192     |
# | time/              |          |
# |    fps             | 3327     |
# |    iterations      | 1        |
# |    time_elapsed    | 0        |
# |    total_timesteps | 2048     |
# ---------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 94.2         |
# |    ep_rew_mean          | -204         |
# | time/                   |              |
# |    fps                  | 2655         |
# |    iterations           | 2            |
# |    time_elapsed         | 1            |
# |    total_timesteps      | 4096         |
# | train/                  |              |
# |    approx_kl            | 0.0054878006 |
# |    clip_fraction        | 0.00903      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.38        |
# |    explained_variance   | -0.003       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 680          |
# |    n_updates            | 10           |
# |    policy_gradient_loss | -0.00421     |
# |    value_loss           | 1.53e+03     |
# ------------------------------------------
# Using cpu device
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 89.7     |
# |    ep_rew_mean     | -192     |
# | time/              |          |
# |    fps             | 2646     |
# |    iterations      | 1        |
# |    time_elapsed    | 0        |
# |    total_timesteps | 2048     |
# ---------------------------------
# ----------------------------------------
# | rollout/                  |          |
# |    ep_len_mean            | 92.9     |
# |    ep_rew_mean            | -179     |
# | time/                     |          |
# |    fps                    | 2876     |
# |    iterations             | 2        |
# |    time_elapsed           | 1        |
# |    total_timesteps        | 4096     |
# | train/                    |          |
# |    explained_variance     | -0.003   |
# |    is_line_search_success | 1        |
# |    kl_divergence_loss     | 0.00432  |
# |    learning_rate          | 0.001    |
# |    n_updates              | 1        |
# |    policy_objective       | 0.0122   |
# |    value_loss             | 1.38e+03 |
# ----------------------------------------
# Using cpu device
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 87.9     |
# |    ep_rew_mean     | -146     |
# | time/              |          |
# |    fps             | 3580     |
# |    iterations      | 1        |
# |    time_elapsed    | 0        |
# |    total_timesteps | 2048     |
# ---------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 88.8        |
# |    ep_rew_mean          | -158        |
# | time/                   |             |
# |    fps                  | 2681        |
# |    iterations           | 2           |
# |    time_elapsed         | 1           |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.009863567 |
# |    clip_fraction        | 0.0492      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.38       |
# |    explained_variance   | 0.000958    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 377         |
# |    n_updates            | 10          |
# |    policy_gradient_loss | -0.00841    |
# |    value_loss           | 1.05e+03    |
# -----------------------------------------
# Using cpu device
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 87.9     |
# |    ep_rew_mean     | -146     |
# | time/              |          |
# |    fps             | 3720     |
# |    iterations      | 1        |
# |    time_elapsed    | 0        |
# |    total_timesteps | 2048     |
# ---------------------------------
# ----------------------------------------
# | rollout/                  |          |
# |    ep_len_mean            | 93.5     |
# |    ep_rew_mean            | -143     |
# | time/                     |          |
# |    fps                    | 3409     |
# |    iterations             | 2        |
# |    time_elapsed           | 1        |
# |    total_timesteps        | 4096     |
# | train/                    |          |
# |    explained_variance     | 0.000958 |
# |    is_line_search_success | 1        |
# |    kl_divergence_loss     | 0.0045   |
# |    learning_rate          | 0.001    |
# |    n_updates              | 1        |
# |    policy_objective       | 0.0205   |
# |    value_loss             | 943      |
# ----------------------------------------

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

def compute_moving_average(data, window_size=100):
    data = data.copy()
    data["Moving_Avg"] = (
        data.groupby(["Algorithm", "Seed"])["Reward"]
        .transform(lambda x: x.rolling(window_size, min_periods=1).mean())
    )
    return data

def plot_moving_average_across_seeds(data, window_size=100):
    sns.set(style="whitegrid")
    algorithms = data["Algorithm"].unique()

    for algorithm in algorithms:
        plt.figure(figsize=(14, 8))
        sns.lineplot(
            data=data[data["Algorithm"] == algorithm],
            x="Episode",
            y="Moving_Avg",
            hue="Seed",
            estimator=None  # Plot raw moving averages for each seed
        )
        plt.title(f"{algorithm}: Moving Average of Rewards Across Seeds (Window = {window_size})")
        plt.xlabel("Episodes")
        plt.ylabel("Moving Average Reward")
        plt.ylim(-400, 250)  # Fix y-axis range
        plt.legend(title="Seed")
        plt.grid(True)
        plt.show()

# Configuration
window_size = 30  # Moving average window size

# Compute moving averages
results_with_moving_avg = compute_moving_average(results_df, window_size)

# Plot moving averages with fixed y-axis
plot_moving_average_across_seeds(results_with_moving_avg, window_size)

# %%
ppo_model = PPO.load("ppo_seed_long_hyper_42")
# Out:
# /home/pranaypalem/.local/lib/python3.10/site-packages/stable_baselines3/common/on_policy_algorithm.py:150: UserWarning: You are trying to run PPO on the GPU, but it is primarily intended to run on the CPU when not using a CNN policy (you are using ActorCriticPolicy which should be a MlpPolicy). See https://github.com/DLR-RM/stable-baselines3/issues/1245 for more info. You can pass `device='cpu'` or `export CUDA_VISIBLE_DEVICES=` to force using the CPU.Note: The model will train, but the GPU utilization will be poor and the training might take longer than on CPU.
#   warnings.warn(

# %%
# Rendering the environment for PPO agent
print("Rendering PPO agent in the environment...")
render_env = gym.make(env_name, render_mode = 'human')
obs, info = render_env.reset(seed=2024)  # Adjust for gymnasium API
for _ in range(10000):
    action, _ = ppo_model.predict(obs, deterministic=True)
    obs, reward, done, truncated, _ = render_env.step(action)
    render_env.render()  # No mode argument required
    if done or truncated:
        break
render_env.close()
# Out:
# Rendering PPO agent in the environment...

# %%
trpo_model1 = TRPO.load("trpo_seed_long_hyper_999")
# Out:
# /home/pranaypalem/.local/lib/python3.10/site-packages/stable_baselines3/common/on_policy_algorithm.py:150: UserWarning: You are trying to run TRPO on the GPU, but it is primarily intended to run on the CPU when not using a CNN policy (you are using ActorCriticPolicy which should be a MlpPolicy). See https://github.com/DLR-RM/stable-baselines3/issues/1245 for more info. You can pass `device='cpu'` or `export CUDA_VISIBLE_DEVICES=` to force using the CPU.Note: The model will train, but the GPU utilization will be poor and the training might take longer than on CPU.
#   warnings.warn(

# %%
# Rendering the environment for TRPO agent
print("Rendering TRPO agent in the environment...")
render_env = gym.make(env_name, render_mode = 'human')
obs, info = render_env.reset(seed=999)  # Adjust for gymnasium API
for _ in range(10000):
    action, _ = trpo_model.predict(obs, deterministic=True)
    obs, reward, done, truncated, _ = render_env.step(action)
    render_env.render()  # No mode argument required
    if done or truncated:
        break
render_env.close()

# vec_env.close()
# Out:
# Rendering TRPO agent in the environment...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[13], line 7
#       5 for _ in range(10000):
#       6     action, _ = trpo_model.predict(obs, deterministic=True)
# ----> 7     obs, reward, done, truncated, _ = render_env.step(action)
#       8     render_env.render()  # No mode argument required
#       9     if done or truncated:
#
# File ~/.local/lib/python3.10/site-packages/gymnasium/wrappers/common.py:125, in TimeLimit.step(self, action)
#     112 def step(
#     113     self, action: ActType
#     114 ) -> tuple[ObsType, SupportsFloat, bool, bool, dict[str, Any]]:
#     115     """Steps through the environment and if the number of steps elapsed exceeds ``max_episode_steps`` then truncate.
#     116
#     117     Args:
#    (...)
#     123
#     124     """
# --> 125     observation, reward, terminated, truncated, info = self.env.step(action)
#     126     self._elapsed_steps += 1
#     128     if self._elapsed_steps >= self._max_episode_steps:
#
# File ~/.local/lib/python3.10/site-packages/gymnasium/wrappers/common.py:393, in OrderEnforcing.step(self, action)
#     391 if not self._has_reset:
#     392     raise ResetNeeded("Cannot call env.step() before calling env.reset()")
# --> 393 return super().step(action)
#
# File ~/.local/lib/python3.10/site-packages/gymnasium/core.py:322, in Wrapper.step(self, action)
#     318 def step(
#     319     self, action: WrapperActType
#     320 ) -> tuple[WrapperObsType, SupportsFloat, bool, bool, dict[str, Any]]:
#     321     """Uses the :meth:`step` of the :attr:`env` that can be overwritten to change the returned data."""
# --> 322     return self.env.step(action)
#
# File ~/.local/lib/python3.10/site-packages/gymnasium/wrappers/common.py:285, in PassiveEnvChecker.step(self, action)
#     283     return env_step_passive_checker(self.env, action)
#     284 else:
# --> 285     return self.env.step(action)
#
# File ~/.local/lib/python3.10/site-packages/gymnasium/envs/box2d/lunar_lander.py:665, in LunarLander.step(self, action)
#     662     reward = +100
#     664 if self.render_mode == "human":
# --> 665     self.render()
#     666 # truncation=False as the time limit is handled by the `TimeLimit` wrapper added during `make`
#     667 return np.array(state, dtype=np.float32), reward, terminated, False, {}
#
# File ~/.local/lib/python3.10/site-packages/gymnasium/envs/box2d/lunar_lander.py:778, in LunarLander.render(self)
#     776     self.screen.blit(self.surf, (0, 0))
#     777     pygame.event.pump()
# --> 778     self.clock.tick(self.metadata["render_fps"])
#     779     pygame.display.flip()
#     780 elif self.render_mode == "rgb_array":
#
# KeyboardInterrupt:
